# %%
import pandas as pd

import sklearn

from sklearn.neighbors import NearestNeighbors

# %%
df1 = pd.read_csv('SpotifyAudioFeaturesApril2019.csv')

# %%
df1.head()
# Out:
#   artist_name                track_id  \
# 0          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1          YG  1tHDG53xJNGsItRA3vfVgs
# 2       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
#
#                                        track_name  acousticness  danceability  \
# 0  Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820         0.743
# 1                    BAND DRUM (feat. A$AP Rocky)      0.024400         0.846
# 2                                   Radio Silence      0.025000         0.603
# 3                                         Lactose      0.029400         0.800
# 4                             Same - Original mix      0.000035         0.783
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       238373   0.339             0.000    1    0.0812    -7.678     1
# 1       214800   0.557             0.000    8    0.2860    -7.259     1
# 2       138913   0.723             0.000    9    0.0824    -5.890     0
# 3       125381   0.579             0.912    5    0.0994   -12.118     0
# 4       124016   0.792             0.878    7    0.0332   -10.277     1
#
#    speechiness    tempo  time_signature  valence  popularity
# 0       0.4090  203.927               4    0.118          15
# 1       0.4570  159.009               4    0.371           0
# 2       0.0454  114.966               4    0.382          56
# 3       0.0701  123.003               4    0.641           0
# 4       0.0661  120.047               4    0.928           0

# %%
df1.describe()
# Out:
#         acousticness   danceability   duration_ms         energy  \
# count  130663.000000  130663.000000  1.306630e+05  130663.000000
# mean        0.342500       0.581468  2.126331e+05       0.569196
# std         0.345641       0.190077  1.231551e+05       0.260312
# min         0.000000       0.000000  3.203000e+03       0.000000
# 25%         0.031600       0.459000  1.639225e+05       0.396000
# 50%         0.203000       0.605000  2.019010e+05       0.603000
# 75%         0.636000       0.727000  2.410475e+05       0.775000
# max         0.996000       0.996000  5.610020e+06       1.000000
#
#        instrumentalness            key       liveness       loudness  \
# count     130663.000000  130663.000000  130663.000000  130663.000000
# mean           0.224018       5.231894       0.194886      -9.974006
# std            0.360328       3.602701       0.167733       6.544379
# min            0.000000       0.000000       0.000000     -60.000000
# 25%            0.000000       2.000000       0.097500     -11.898000
# 50%            0.000149       5.000000       0.124000      -7.979000
# 75%            0.440000       8.000000       0.236000      -5.684000
# max            1.000000      11.000000       0.999000       1.806000
#
#                 mode    speechiness          tempo  time_signature  \
# count  130663.000000  130663.000000  130663.000000   130663.000000
# mean        0.607739       0.112015     119.473353        3.878986
# std         0.488256       0.124327      30.159636        0.514403
# min         0.000000       0.000000       0.000000        0.000000
# 25%         0.000000       0.038900      96.014000        4.000000
# 50%         1.000000       0.055900     120.027000        4.000000
# 75%         1.000000       0.129000     139.642000        4.000000
# max         1.000000       0.966000     249.983000        5.000000
#
#              valence     popularity
# count  130663.000000  130663.000000
# mean        0.439630      24.208988
# std         0.259079      19.713191
# min         0.000000       0.000000
# 25%         0.224000       7.000000
# 50%         0.420000      22.000000
# 75%         0.638000      38.000000
# max         1.000000     100.000000

# %%
df1.columns
# Out:
# Index(['artist_name', 'track_id', 'track_name', 'acousticness', 'danceability',
#        'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness',
#        'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence',
#        'popularity'],
#       dtype='object')

# %%
df2 = pd.read_csv("SpotifyAudioFeaturesNov2018.csv")

# %%
tracks = pd.concat([df1,df2]).drop_duplicates().reset_index(drop=True)

# %%
data_cols_2 = ['acousticness',
               'danceability',
               'energy',
               'instrumentalness',
               'liveness',
               'loudness',
               'speechiness',
               'tempo',
               'valence'
              ]

# data_cols_2 = ['acousticness', 'danceability',
#        'duration_ms', 'energy', 'instrumentalness', 'liveness',
#        'loudness', 'speechiness', 'tempo', 'valence',
#        'popularity']

# %%
prenorm = big_tracks_2[data_cols_2]

# %%
prenorm.head()
# Out:
#    acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0      0.005820         0.743   0.339             0.000    0.0812    -7.678
# 1      0.024400         0.846   0.557             0.000    0.2860    -7.259
# 2      0.025000         0.603   0.723             0.000    0.0824    -5.890
# 3      0.029400         0.800   0.579             0.912    0.0994   -12.118
# 4      0.000035         0.783   0.792             0.878    0.0332   -10.277
#
#    speechiness    tempo  valence
# 0       0.4090  203.927    0.118
# 1       0.4570  159.009    0.371
# 2       0.0454  114.966    0.382
# 3       0.0701  123.003    0.641
# 4       0.0661  120.047    0.928

# %%
scaler =  sklearn.preprocessing.MinMaxScaler()

# %%
scaler_2 = sklearn.preprocessing.StandardScaler()

# %%
normed_arr = scaler.fit_transform(prenorm)

# %%
# normed_arr = scaler_2.fit_transform(prenorm)

# %%
# data_cols = ['acousticness', 'danceability',
#        'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness',
#        'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence',
#        'popularity']

# %%
normed = pd.DataFrame(normed_arr, columns = data_cols_2)

# %%
normed.shape
# Out:
# (292406, 9)

# %%
normed.head()
# Out:
#    acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0      0.005843      0.745984   0.339             0.000    0.0812  0.820815
# 1      0.024498      0.849398   0.557             0.000    0.2860  0.827388
# 2      0.025100      0.605422   0.723             0.000    0.0824  0.848864
# 3      0.029518      0.803213   0.579             0.912    0.0994  0.751161
# 4      0.000035      0.786145   0.792             0.878    0.0332  0.780042
#
#    speechiness     tempo  valence
# 0     0.422958  0.815763    0.118
# 1     0.472596  0.636079    0.371
# 2     0.046949  0.459895    0.382
# 3     0.072492  0.492045    0.641
# 4     0.068356  0.480221    0.928

# %%
normed.describe()
# Out:
#         acousticness   danceability         energy  instrumentalness  \
# count  292406.000000  292406.000000  292406.000000     292406.000000
# mean        0.383541       0.557803       0.560606          0.198994
# std         0.362110       0.192570       0.271203          0.343451
# min         0.000000       0.000000       0.000000          0.000000
# 25%         0.038855       0.431727       0.362000          0.000000
# 50%         0.253012       0.577309       0.596000          0.000112
# 75%         0.752008       0.703815       0.784000          0.233000
# max         1.000000       1.000000       1.000000          1.000000
#
#             liveness       loudness    speechiness          tempo  \
# count  292406.000000  292406.000000  292406.000000  292406.000000
# mean        0.213292       0.781714       0.125218       0.472180
# std         0.196210       0.102027       0.183320       0.123546
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.097400       0.743286       0.038883       0.374694
# 50%         0.127000       0.812688       0.053361       0.471928
# 75%         0.262000       0.851908       0.114788       0.554744
# max         1.000000       1.000000       1.000000       1.000000
#
#              valence
# count  292406.000000
# mean        0.447151
# std         0.265846
# min         0.000000
# 25%         0.221000
# 50%         0.432000
# 75%         0.658000
# max         1.000000

# %%
neighbors = NearestNeighbors(metric='euclidean')

# %%
neighbors.fit(normed)
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='euclidean',
#                  metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                  radius=1.0)

# %%
test = big_tracks_2[big_tracks_2['artist_name'] == 'Ramones'].copy()
test_beat = big_tracks_2[big_tracks_2['track_id'] == '183Klch3PBWLz2S6zNUVxR'].copy()

# %%
# test_cols = test[data_cols]
# test_beat_cols = test_beat[data_cols]
test_cols = test[data_cols_2]
test_beat_cols = test_beat[data_cols_2]

# %%
test_cols
# Out:
#    acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0      0.000298      0.437751   0.697          0.429000    0.0842  0.849915
# 1      0.098494      0.421687   0.965          0.000335    0.0784  0.910109
# 2      0.000270      0.386546   0.783          0.470000    0.1080  0.901528
# 3      0.169679      0.599398   0.960          0.000029    0.1050  0.878687
#
#    speechiness     tempo  valence
# 0     0.133402  0.705688    0.887
# 1     0.041675  0.705020    0.846
# 2     0.240951  0.706852    0.902
# 3     0.043433  0.652112    0.937

# %%
test_mean = test_cols.mean(axis=0)
test_mean = pd.DataFrame(test_mean).T.copy()
test_mean
# Out:
#    acousticness  danceability   energy  instrumentalness  liveness  loudness  \
# 0      0.067185      0.461345  0.85125          0.224841    0.0939   0.88506
#
#    speechiness     tempo  valence
# 0     0.114866  0.692418    0.893

# %%
# test_cols = pd.DataFrame(test_cols.loc[20254], columns=data_cols_2)

# %%
test_cols = pd.DataFrame(scaler.transform(test_cols), columns=data_cols_2)
# test_cols = pd.DataFrame(scaler_2.transform(test_cols), columns=data_cols)
test_beat_cols = pd.DataFrame(scaler.transform(test_beat_cols), columns=data_cols_2)
# test_beat_cols = pd.DataFrame(scaler_2.transform(test_beat_cols), columns=data_cols)

# %%
ramones = neighbors.kneighbors(test_cols, return_distance=False)

# %%
ramones_mean = neighbors.kneighbors(test_mean, return_distance=False)

# %%
result = neighbors.kneighbors(test_beat_cols, return_distance=False)

# %%
neighbors.kneighbors(test_cols, return_distance=False)
# Out:
# array([[ 20254, 288824, 171554,  12639,  14683],
#        [232916, 233858, 233525,  55186, 259936],
#        [288824,  20254, 152778,  48655, 259230],
#        [288948, 101444, 260595, 233235, 140437]])

# %%
ramones_mean
# Out:
# array([[  6284, 264321, 176305, 137449,  12375]])

# %%
for n in range(4):
    for i in ramones[n]:
        print (big_tracks_2.iloc[i]['artist_name'])
        print (big_tracks_2.iloc[i]['track_name'])
    print('\n')

# %%
for i in ramones_mean:
    print (big_tracks_2.iloc[i]['artist_name'])
    print (big_tracks_2.iloc[i]['track_name'])
# Out:
# 6284                The Drums
# 264321    Dance Hall Crashers
# 176305           Robert Plant
# 137449            Josh Turner
# 12375                  purpan
# Name: artist_name, dtype: object
# 6284                 Meet Me In Mexico
# 264321                    Buried Alive
# 176305    Let Your Loss Be Your Lesson
# 137449             Deeper Than My Love
# 12375                        Wonderful
# Name: track_name, dtype: object

# %%
for i in result[0]:
    print (big_tracks_2.iloc[i])
# Out:
# artist_name                             The Beatles
# track_name          Back In The U.S.S.R. - 2018 Mix
# track_id                     183Klch3PBWLz2S6zNUVxR
# acousticness                                0.00102
# danceability                                   0.51
# duration_ms                                  163467
# energy                                        0.893
# instrumentalness                           5.85e-05
# liveness                                      0.201
# loudness                                     -9.267
# speechiness                                  0.0342
# tempo                                       142.657
# valence                                       0.934
# popularity                                       64
# Name: 126903, dtype: object
# artist_name                  Twisted Sister
# track_name          We're Not Gonna Take It
# track_id             1hlveB9M6ijHZRbzZ2teyh
# acousticness                         0.0127
# danceability                          0.502
# duration_ms                          219667
# energy                                0.924
# instrumentalness                          0
# liveness                              0.162
# loudness                             -6.299
# speechiness                          0.0503
# tempo                               149.186
# valence                               0.922
# popularity                               73
# Name: 241884, dtype: object
# artist_name                                              NOFX
# track_name          There's No 'Too Soon' If Time is Relative
# track_id                               1IQqL8tzIVdCrt53HBBO6S
# acousticness                                            0.013
# danceability                                            0.501
# duration_ms                                            128210
# energy                                                  0.876
# instrumentalness                                     0.000418
# liveness                                                0.224
# loudness                                               -7.316
# speechiness                                            0.0504
# tempo                                                 149.496
# valence                                                 0.875
# popularity                                                 37
# Name: 10982, dtype: object
# artist_name                       Old 97's
# track_name             Champaign, Illinois
# track_id            5Ed2crPH1EuxwI1iUKZlnD
# acousticness                       0.00232
# danceability                         0.548
# duration_ms                         205387
# energy                               0.877
# instrumentalness                  9.49e-06
# liveness                             0.223
# loudness                            -5.647
# speechiness                         0.0348
# tempo                              140.063
# valence                              0.887
# popularity                              40
# Name: 137711, dtype: object
# artist_name              Jeffries Fan Club
# track_name                   She's So Cool
# track_id            1zG951vjcbdKmttLWK44EZ
# acousticness                        0.0142
# danceability                         0.502
# duration_ms                         203825
# energy                               0.917
# instrumentalness                   0.00143
# liveness                             0.183
# loudness                            -8.826
# speechiness                         0.0539
# tempo                              123.281
# valence                               0.91
# popularity                              18
# Name: 262257, dtype: object

# %%
# df2 = pd.read_csv("SpotifyAudioFeaturesNov2018.csv")

# %%
df2.head()
# Out:
#   artist_name                track_id  \
# 0          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1          YG  1tHDG53xJNGsItRA3vfVgs
# 2       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
#
#                                        track_name  acousticness  danceability  \
# 0  Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820         0.743
# 1                    BAND DRUM (feat. A$AP Rocky)      0.024400         0.846
# 2                                   Radio Silence      0.025000         0.603
# 3                                         Lactose      0.029400         0.800
# 4                             Same - Original mix      0.000035         0.783
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       238373   0.339             0.000    1    0.0812    -7.678     1
# 1       214800   0.557             0.000    8    0.2860    -7.259     1
# 2       138913   0.723             0.000    9    0.0824    -5.890     0
# 3       125381   0.579             0.912    5    0.0994   -12.118     0
# 4       124016   0.792             0.878    7    0.0332   -10.277     1
#
#    speechiness    tempo  time_signature  valence  popularity
# 0       0.4090  203.927               4    0.118          44
# 1       0.4570  159.009               4    0.371          10
# 2       0.0454  114.966               4    0.382          63
# 3       0.0701  123.003               4    0.641           9
# 4       0.0661  120.047               4    0.928           8

# %%
df_merge = df1.merge(df2, how = 'inner' ,indicator=False)
df_merge.shape, df2.shape, df1.shape
# Out:
# ((24891, 17), (116372, 17), (130663, 17))

# %%
df_diff = df1.merge(df2, how = 'outer' ,indicator=True).loc[lambda x : x['_merge']=='left_only']

# %%
df_diff.shape
# Out:
# (105772, 18)

# %%
# tracks = pd.concat([df1,df2]).drop_duplicates().reset_index(drop=True)

# %%
tracks.shape
# Out:
# (222144, 17)

# %%
big_tracks_2[big_tracks_2['artist_name'] == 'The Beatles']
# Out:
#         artist_name                                         track_name  \
# 113165  The Beatles                  Back In The U.S.S.R. - Esher Demo
# 115843  The Beatles   The Continuing Story Of Bungalow Bill - 2018 Mix
# 116065  The Beatles                                 Piggies - 2018 Mix
# 116337  The Beatles                         Dear Prudence - Esher Demo
# 117184  The Beatles                          Wild Honey Pie - 2018 Mix
# ...             ...                                                ...
# 289475  The Beatles                Eight Days A Week - Remastered 2015
# 289502  The Beatles                     Love Me Do - Mono / Remastered
# 289521  The Beatles                Run For Your Life - Remastered 2009
# 289533  The Beatles  I'm Happy Just To Dance With You - Remastered ...
# 289534  The Beatles                         No Reply - Remastered 2009
#
#                       track_id  acousticness  danceability  duration_ms  \
# 113165  7KdX4AwTqPHmTe2OOIHjk0        0.7560         0.658       179907
# 115843  7KXaC0HCD4VoIZOzWfdirZ        0.2950         0.659       194187
# 116065  1koFbbNy8BJvG63B0ExZEQ        0.2000         0.527       124307
# 116337  0dPsctAum4J6B9Z2xTRz2A        0.6550         0.387       287053
# 117184  76YBf6AwWhPG62H2LZftFQ        0.2780         0.749        53000
# ...                        ...           ...           ...          ...
# 289475  5ylLypaOksxWd75YrGtx2N        0.2650         0.636       163320
# 289502  4aX3n1Pn6jiCbvqBL8eqyP        0.4040         0.524       140173
# 289521  4gUYV3ktbaOeAK5KrXMWV5        0.0103         0.563       141093
# 289533  0gd50I2gKioJ59C827EdAY        0.1380         0.658       116373
# 289534  4ltC6PrqkTtpcRNi5lvS4z        0.6700         0.718       136067
#
#         energy  instrumentalness  liveness  loudness  speechiness    tempo  \
# 113165   0.530          0.000000    0.1850    -8.480       0.0845  127.719
# 115843   0.560          0.000000    0.6830    -9.561       0.0648  114.796
# 116065   0.471          0.000000    0.0981    -9.901       0.0314   92.583
# 116337   0.266          0.012900    0.1430   -12.380       0.0302   89.173
# 117184   0.689          0.759000    0.7960   -10.883       0.0346   89.897
# ...        ...               ...       ...       ...          ...      ...
# 289475   0.677          0.000000    0.2150    -5.605       0.0316  138.707
# 289502   0.880          0.000191    0.1540    -3.865       0.0987  148.058
# 289521   0.705          0.000000    0.0552    -9.232       0.1030  176.732
# 289533   0.537          0.000000    0.0572    -7.535       0.0307  132.115
# 289534   0.593          0.000000    0.1720    -9.976       0.0377  124.251
#
#         valence  popularity
# 113165    0.557           5
# 115843    0.738          52
# 116065    0.571          51
# 116337    0.271          45
# 117184    0.299          52
# ...         ...         ...
# 289475    0.837          57
# 289502    0.758          58
# 289521    0.822          58
# 289533    0.887          58
# 289534    0.869          58
#
# [159 rows x 14 columns]

# %%
testa = tracks.iloc[146624]

# %%
testb = tracks.iloc[20266]

# %%
test_beat = tracks.iloc[127174]

# %%
test_beat
# Out:
# artist_name                             The Beatles
# track_id                     183Klch3PBWLz2S6zNUVxR
# track_name          Back In The U.S.S.R. - 2018 Mix
# acousticness                                0.00102
# danceability                                   0.51
# duration_ms                                  163467
# energy                                        0.893
# instrumentalness                           5.85e-05
# key                                               9
# liveness                                      0.201
# loudness                                     -9.267
# mode                                              1
# speechiness                                  0.0342
# tempo                                       142.657
# time_signature                                    4
# valence                                       0.934
# popularity                                       64
# Name: 127174, dtype: object

# %%
df3 = pd.read_csv('SpotifyFeatures.csv')

# %%
df3_nog.head()
# Out:
#          artist_name                        track_name  \
# 0     Henri Salvador       C'est beau de faire un Show
# 1  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# 1       137373   0.737             0.000  F#    0.1510    -5.559  Minor
# 2       170267   0.131             0.000   C    0.1030   -13.879  Minor
# 3       152427   0.326             0.000  C#    0.0985   -12.178  Major
# 4        82625   0.225             0.123   F    0.2020   -21.150  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390

# %%
df3_nog = df3.drop(columns =['genre']).copy()

# %%
tracks_diff = tracks[small_cols].merge(df3_nog[small_cols], how = 'outer' ,indicator=True).loc[lambda x : x['_merge']=='left_only']
tracks_diff.shape, tracks.shape, df3.shape
# Out:
# ((220116, 12), (222144, 17), (232725, 18))

# %%
tracks.dtypes
# Out:
# artist_name          object
# track_id             object
# track_name           object
# acousticness        float64
# danceability        float64
# duration_ms           int64
# energy              float64
# instrumentalness    float64
# key                   int64
# liveness            float64
# loudness            float64
# mode                  int64
# speechiness         float64
# tempo               float64
# time_signature        int64
# valence             float64
# popularity            int64
# dtype: object

# %%
df3_nog[['time_signature', 'key']]
# Out:
# artist_name          object
# track_name           object
# track_id             object
# popularity            int64
# acousticness        float64
# danceability        float64
# duration_ms           int64
# energy              float64
# instrumentalness    float64
# key                  object
# liveness            float64
# loudness            float64
# mode                 object
# speechiness         float64
# tempo               float64
# time_signature       object
# valence             float64
# dtype: object

# %%
small_cols = ['artist_name',
              'track_name',
              'track_id',
              'acousticness',
              'danceability',
              'duration_ms',
              'energy',
              'instrumentalness',
              'liveness',
              'loudness',
              'speechiness',
              'tempo',
              'valence',
              'popularity']

# %%
tracks.duplicated(subset=['track_id']).value_counts()
# Out:
# False    130989
# True      91155
# dtype: int64

# %%
big_tracks = pd.concat([tracks[small_cols], df3_nog[small_cols]]).drop_duplicates().reset_index(drop=True)

# %%
big_tracks.shape
# Out:
# (411255, 14)

# %%
big_tracks_2 = pd.concat([tracks[small_cols], df3_nog[small_cols]]).drop_duplicates(subset=['track_id']).reset_index(drop=True)

# %%
big_tracks.duplicated(subset=['track_id']).value_counts()
# Out:
# False    292406
# True     118849
# dtype: int64

# %%
big_tracks_2.shape
# Out:
# (292406, 14)

# %%
import pickle

# %%
filename = 'model_1.pkl'

# %%
pickle.dump(neighbors, open(filename, 'wb'))
